# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("imu.csv",usecols =['Gyroscope Z'])
print(df)
# Out:
#         Gyroscope Z
# 0         -1.708984
# 1         -1.525879
# 2         -1.342774
# 3         -1.159668
# 4          1.403809
# ...             ...
# 119905    -0.610352
# 119906    -0.610352
# 119907    -0.610352
# 119908    -0.549316
# 119909    -0.549316
#
# [119910 rows x 1 columns]

# %%
C=90.123
C1=0.4
C2=0.66
cfc=0
a=df.values.tolist()
b=np.array(a)
d=df.count()
type(b)
print(d)
print(b[0])
# Out:
# Gyroscope Z    119910
# dtype: int64
# [-1.708984]

# %%
def find_peaks(df):
    peaks = []
    for i in range(1, len(df) - 1):
        if df[i] < df[i-1] and df[i] < df[i+1]:
            peaks.append(df[i])
    return peaks

# %%
d=find_peaks(b)
print(d)
# Out:
# [array([-1.77002]), array([-2.441406]), array([-16.235353]), array([-5.737305]), array([-9.70459]), array([-3.356934]), array([-2.990723]), array([-1.647949]), array([-11.59668]), array([-2.990723]), array([-1.708984]), array([-2.624512]), array([-0.427246]), array([-0.976563]), array([-1.464844]), array([-2.929688]), array([-2.136231]), array([-1.831055]), array([-5.371094]), array([-6.652832]), array([-1.647949]), array([3.417969]), array([4.455567]), array([2.563477]), array([3.417969]), array([17.639161]), array([-9.521485]), array([-10.131837]), array([-1.403809]), array([-5.859375]), array([28.381349]), array([23.559572]), array([22.399904]), array([-62.561039]), array([-36.376955]), array([-57.617191]), array([132.263192]), array([91.613775]), array([213.012708]), array([247.192398]), array([204.833997]), array([-76.538091]), array([-81.604009]), array([-67.810063]), array([-70.007328]), array([-168.151866]), array([-204.16261]), array([49.43848]), array([-213.378919]), array(
# ...

# %%
def find_valley(df):
    valley = []
    for i in range(1, len(df) - 1):
        if df[i] > df[i-1] and df[i] > df[i+1]:
            valley.append(df[i])
    return valley
e=find_valley(b)
print(e)
# Out:
# [array([8.728028]), array([-1.098633]), array([8.728028]), array([0.610352]), array([-4.211426]), array([-2.502442]), array([-2.441406]), array([-1.159668]), array([1.77002]), array([-1.159668]), array([-0.732422]), array([-1.220703]), array([3.112793]), array([0.244141]), array([-0.183105]), array([-1.708984]), array([-1.098633]), array([-1.647949]), array([-0.305176]), array([-0.976563]), array([15.747071]), array([9.521485]), array([4.699707]), array([4.272461]), array([18.005372]), array([17.761232]), array([-8.300782]), array([-1.159668]), array([4.394532]), array([43.701175]), array([46.752933]), array([28.137209]), array([378.295922]), array([558.89896]), array([289.489764]), array([229.00392]), array([166.07667]), array([222.534193]), array([262.268082]), array([375.976585]), array([276.184099]), array([-47.241214]), array([39.855959]), array([-50.720218]), array([-36.682131]), array([-109.008796]), array([206.237806]), array([147.277841]), array([300.231952]), array([125.854
# ...

# %%
f=len(d)+len(e)
print(f)
h=len(d)-len(e)
print(h)
def countlist(valley,peak):
    return[sub[item] for item in range(len(d))
                     for sub in[valley,peak]]

com=(countlist(find_peaks(b),find_valley(b)))
type(com)
g=np.array(com)
print(g)
# Out:
# 32163
# -45
# [[-1.77002 ]
#  [ 8.728028]
#  [-2.441406]
#  ...
#  [-0.549316]
#  [-0.610352]
#  [-0.549316]]

# %%
C=90.123
cfc=0
for i in range(1,len(b)):
    if((b[i]-C)*(b[i-1]-C)<0):
        cfc=cfc+1
        if(cfc==2):

# %%
#to classify vpvp
outcom=[]

for i in range(f):
    if
# Out:
# [0, 1]
# [0, 1]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[85], line 31
#      29                 ms.append(b[i])
#      30             if(g[i]>0):
# ---> 31                 lc.pop()
#      32 print('FIRST TOUCH')
#      33 print(fc)
#
# IndexError: pop from empty list

# %%
ft=len(fc)
lamc=len(lam)
lt=len(lc)
msc=len(ms)
print(ft)
print(lamc)
print(lt)
print(msc)
type(fc)
# Out:
# 0
# 1
# 0
# 1
# list
